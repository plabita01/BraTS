# %% [markdown]
# # Brain Tumor Segmentation  Unet Experiments

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
f="/content/drive/MyDrive/archive.zip"
with ZipFile(f,'r') as z:
  z.extractall()
  print('done')
# Out:
# done

# %% [markdown]
# **The process of segmenting tumor from MRI image of a brain is one of the highly focused areas in the community of medical science as MRI is noninvasive imaging. Therefore, I decided to create Brain Tumor Segmentation Notebook  that you can easily use the capabilities of this powerful tool. I am currently in the early stages of designing this Notebook and will be constantly updating these codes to get to a usable version.**

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.layers as layers
from sklearn.model_selection import train_test_split
import keras
from keras.models import Model, load_model
from keras.layers import Input ,BatchNormalization , Activation
from keras.layers.convolutional import Conv2D, UpSampling2D
from keras.layers.pooling import MaxPooling2D
#from keras.layers.merge import concatenate
from tensorflow.keras.layers import Concatenate, concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
from sklearn.model_selection import train_test_split
import os
import nibabel as nib
import cv2 as cv
import matplotlib.pyplot as plt
from keras import backend as K
import glob
import skimage.io as io
import skimage.color as color
import random as r
import math
! pip install nilearn
from nilearn import plotting
#for dirname, _, filenames in os.walk('/kaggle/input'):
for dirname, _, filenames in os.walk('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData'):

    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Collecting nilearn
#   Downloading nilearn-0.10.1-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.3.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.9.3)
# Requirement already satisfied: nibabel>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.0.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nilearn) (23.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (2.27.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel>=3.2.0->nilearn) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->nilearn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->nilearn) (1.16.0)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.10.1
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/survival_info.csv
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/name_mapping.csv
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306/BraTS20_Training_306_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306/BraTS20_Training_306_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306/BraTS20_Training_306_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306/BraTS20_Training_306_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306/BraTS20_Training_306_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092/BraTS20_Training_092_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092/BraTS20_Training_092_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092/BraTS20_Training_092_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092/BraTS20_Training_092_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092/BraTS20_Training_092_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349/BraTS20_Training_349_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349/BraTS20_Training_349_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349/BraTS20_Training_349_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349/BraTS20_Training_349_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349/BraTS20_Training_349_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197/BraTS20_Training_197_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197/BraTS20_Training_197_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197/BraTS20_Training_197_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197/BraTS20_Training_197_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197/BraTS20_Training_197_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088/BraTS20_Training_088_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088/BraTS20_Training_088_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088/BraTS20_Training_088_flair.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088/BraTS20_Training_088_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088/BraTS20_Training_088_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_168/BraTS20_Training_168_t2.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_168/BraTS20_Training_168_seg.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_168/BraTS20_Training_168_t1.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_168/BraTS20_Training_168_t1ce.nii
# /content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training
/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_flair.nii')
Flair= nib.load('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_flair.nii')
Seg= nib.load('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_seg.nii')
T1= nib.load('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1.nii')
T1ce= nib.load('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1ce.nii')
T2= nib.load('/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t2.nii')

# %% [markdown]
# **Fluid-attenuated inversion recovery (FLAIR) :**
#
# **FLAIR is an MRI sequence with an inversion recovery set to null fluids. For example, it can be used in brain imaging to suppress cerebrospinal fluid (CSF) effects on the image, so as to bring out the periventricular hyperintense lesions, such as multiple sclerosis (MS) plaques**

# %%
plotting.plot_anat(Flair,cut_coords=[-100, 100, 100],title="Flair",draw_cross =False)

# %% [markdown]
# **Manual segmentation that annotated by an expert**

# %%
plotting.plot_anat(Seg,cut_coords=[-100, 100, 100],title="Seg",draw_cross =False)

# %% [markdown]
# **T1 weighted images :**
#
# **Magnetic resonance imaging uses the resonance of the protons to generate images. Protons are excited by a radio frequency pulse at an appropriate frequency (Larmor frequency) and then the excess energy is released in the form of a minuscule amount of heat to the surroundings as the spins return to their thermal equilibrium. The magnetization of the proton ensemble goes back to its equilibrium value with an exponential curve characterized by a time constant T1.**
#
# **T1 weighted images can be obtained by setting short repetition time (TR) such as < 750 ms and echo time (TE) such as < 40 ms in conventional spin echo sequences, while in Gradient Echo Sequences they can be obtained by using flip angles of larger than 50o while setting TE values to less than 15 ms.**
#
# **T1 is significantly different between grey matter and white matter and is used when undertaking brain scans. A strong T1 contrast is present between fluid and more solid anatomical structures, making T1 contrast suitable for morphological assessment of the normal or pathological anatomy, e.g., for musculoskeletal applications.**

# %%
plotting.plot_anat(T1,cut_coords=[-100, 100, 100],title="T1",draw_cross =False)

# %%
plotting.plot_anat(T1ce,cut_coords=[-100, 100, 100],title="T1ce",draw_cross =False)

# %% [markdown]
# **T2 weighted image :**
#
#
# **T2 weighted image (T2WI) is one of the basic pulse sequences in MRI. The sequence weighting highlights differences in the T2 relaxation time of tissues.**
#
# **The amount of T2 decay a tissue experiences depends on multiple factors. Each tissue has an inherent T2 value, but external factors (such as magnetic field inhomogeneity) can decrease the T2 relaxation time. This additional effect is captured in T2*. The refocusing pulse in spin-echo sequences helps to mitigate these extraneous influences on the T2 relaxation time, trying to keep the image T2 weighted rather than T2* weighted.**

# %%
plotting.plot_anat(T2,cut_coords=[-100, 100, 100],title="T2",draw_cross =False)

# %% [markdown]
# # Data Preprocessing

# %%
Path= '/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData'
#Path='D:/BraTS/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData'
p=os.listdir(Path)
Input_Data= []
def Data_Preprocessing(modalities_dir):
    all_modalities = []
    for modality in modalities_dir:
        nifti_file   = nib.load(modality)
        brain_numpy  = np.asarray(nifti_file.dataobj)
        all_modalities.append(brain_numpy)
    brain_affine   = nifti_file.affine
    all_modalities = np.array(all_modalities)
    all_modalities = np.rint(all_modalities).astype(np.int16)
    all_modalities = all_modalities[:, :, :, :]
    all_modalities = np.transpose(all_modalities)
    return all_modalities
for i in p[:20]:
    brain_dir = os.path.normpath(Path+'/'+i)
    flair     = glob.glob(os.path.join(brain_dir, '*_flair*.nii'))
    t1        = glob.glob(os.path.join(brain_dir, '*_t1*.nii'))
    t1ce      = glob.glob(os.path.join(brain_dir, '*_t1ce*.nii'))
    t2        = glob.glob(os.path.join(brain_dir, '*_t2*.nii'))
    gt        = glob.glob( os.path.join(brain_dir, '*_seg*.nii'))
    # print(np.array(flair).shape)
    modalities_dir = [flair[0], t1[0], t1ce[0], t2[0], gt[0]]
    P_Data = Data_Preprocessing(modalities_dir)
    Input_Data.append(P_Data)

# %% [markdown]
# **Check the output**

# %%
fig = plt.figure(figsize=(5,5))
immmg = Input_Data[1][100,:,:,3]
imgplot = plt.imshow(immmg)
plt.show()

# %% [markdown]
# **concatenate images**

# %%
def Data_Concatenate(Input_Data):
    counter=0
    Output= []
    for i in range(5):
        print('$')
        c=0
        counter=0
        for ii in range(len(Input_Data)):
            if (counter != len(Input_Data)):
                a= Input_Data[counter][:,:,:,i]
                print('a={}'.format(a.shape))
                b= Input_Data[counter+1][:,:,:,i]
                print('b={}'.format(b.shape))
                if(counter==0):
                    c= np.concatenate((a, b), axis=0)
                    print('c1={}'.format(c.shape))
                    counter= counter+2
                else:
                    c1= np.concatenate((a, b), axis=0)
                    c= np.concatenate((c, c1), axis=0)
                    print('c2={}'.format(c.shape))
                    counter= counter+2
        c= c[:,:,:,np.newaxis]
        Output.append(c)
    return Output

# %%
InData= Data_Concatenate(Input_Data)

# %%
AIO= concatenate(InData, axis=3)
#AIO=tf.keras.layers.concatenate(InData, axis=3)
AIO=np.array(AIO,dtype='float32')
TR=np.array(AIO[:,:,:,1],dtype='float32')
TRL=np.array(AIO[:,:,:,4],dtype='float32')

# %%
X_train , X_test, Y_train, Y_test = train_test_split(TR, TRL, test_size=0.15, random_state=32)
AIO=TRL=0

# %% [markdown]
# **Implement Unet**

# %% [markdown]
# **The u-net is convolutional network architecture for fast and precise segmentation of images. Up to now it has outperformed the prior best method (a sliding-window convolutional network) on the ISBI challenge for segmentation of neuronal structures in electron microscopic stacks. It has won the Grand Challenge for Computer-Automated Detection of Caries in Bitewing Radiography at ISBI 2015, and it has won the Cell Tracking Challenge at ISBI 2015 on the two most challenging transmitted light microscopy categories (Phase contrast and DIC microscopy) by a large margin. architecture (example for 32x32 pixels in the lowest resolution). Each blue box corresponds to a multi-channel feature map. The number of channels is denoted on top of the box. The x-y-size is provided at the lower left edge of the box. White boxes represent copied feature maps. The arrows denote the different operations.**

# %%
'''

ATTENTION UNET

'''

def gating_signal(input, out_size, batch_norm=False):

    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def repeat_elem(tensor, rep):
    # lambda function to repeat Repeats the elements of a tensor along an axis
    #by a factor of rep.
    # If tensor has shape (None, 256,256,3), lambda will return a tensor of shape
    #(None, 256,256,6), if specified axis=3 and rep=2.

     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    # print(shape_g[1] , shape_g[2])
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

def conv_block(x, filter_size, size):

    conv = tf.keras.layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    conv = tf.keras.layers.BatchNormalization(axis=3)(conv)
    conv = tf.keras.layers.Activation("relu")(conv)

    conv = tf.keras.layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    conv = tf.keras.layers.BatchNormalization(axis=3)(conv)
    conv = tf.keras.layers.Activation("relu")(conv)

    return conv


def Attention_UNet(input_shape, NUM_CLASSES=1, dropout_rate=0.0, batch_norm=True):
    '''
    Attention UNet,

    '''
    # network structure
    FILTER_NUM = 32
    FILTER_SIZE = 3
    UP_SAMP_SIZE = 2

    inputs = layers.Input(input_shape, dtype=tf.float32)

####### ENCODER
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # print(conv_128.shape)
   # gating_64 = gating_signal(conv_128, 2*FILTER_NUM, batch_norm)
   # att_64 = attention_block(conv_, gating_64, 2*FILTER_NUM)

    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # print(conv_64.shape)

    gating_32 = gating_signal(pool_32, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(conv_64, gating_32, 4*FILTER_NUM)
    pool_32_1 = layers.MaxPooling2D(pool_size=(2,2))(att_32)#########


    conv_32 = conv_block(pool_32_1, FILTER_SIZE, 4*FILTER_NUM)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # print(conv_32.shape)

    gating_16 = gating_signal(pool_16, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(conv_32, gating_16, 8*FILTER_NUM)
    pool_16_1 = layers.MaxPooling2D(pool_size=(2,2))(att_16)#########

    conv_16 = conv_block(pool_16_1, FILTER_SIZE, 8*FILTER_NUM)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # print(conv_16.shape)

    gating_8 = gating_signal(pool_8, 4*FILTER_NUM, batch_norm)
    att_8 = attention_block(conv_16, gating_8, 4*FILTER_NUM)
    pool_8_1 = layers.MaxPooling2D(pool_size=(2,2))(att_8)#########

    conv_8 = conv_block(pool_8_1, FILTER_SIZE, 16*FILTER_NUM)
    # pool_4 = layers.MaxPooling2D(pool_size=(2,2))(conv_8)


####### DECODER
    gating_16 = gating_signal(conv_8, 8*FILTER_NUM, batch_norm)
    # print('shape compare')
    # print(conv_16.shape,gating_16.shape)

    att_16 = attention_block(conv_16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM)
# #############
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    # print(conv_64.shape,gating_32.shape)
    # att_32 = attention_block(conv_64, gating_32, 4*FILTER_NUM)
    att_32 = attention_block(conv_32, gating_32, 4*FILTER_NUM)

    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM)

    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(conv_64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM)

    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(conv_128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)

    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM)
    # print(up_conv_128.shape)


    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('sigmoid')(conv_final)  #Change to softmax for multichannel


    model = Model(inputs, conv_final, name="Attention_UNet")
    return model

# %%
'''

    #  CBAM BETWEEN ENCODER AND DECODER



import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate

def cbam_block(inputs, reduction=16):
    # Channel-wise attention
    channels = inputs.shape[-1]
    avg_pool = tf.reduce_mean(inputs, axis=[1, 2], keepdims=True)
    max_pool = tf.reduce_max(inputs, axis=[1, 2], keepdims=True)
    combined = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(filters=channels // reduction, kernel_size=1, activation='relu')(combined)
    attention = Conv2D(filters=channels, kernel_size=1, activation='sigmoid')(attention)
    channel_attention = tf.multiply(inputs, attention)

    # Spatial-wise attention
    max_pool = tf.reduce_max(channel_attention, axis=-1, keepdims=True)
    attention = Conv2D(filters=1, kernel_size=7, padding='same', activation='sigmoid')(max_pool)
    spatial_attention = tf.multiply(inputs, attention)

    return spatial_attention

def unet_with_cbam(input_shape, num_classes, reduction=16):
    inputs = Input(input_shape)


    encoder_conv1 = Conv2D(128, 3, activation='relu', padding='same')(inputs)
    encoder_pool1 = MaxPooling2D()(encoder_conv1)

    encoder_pool1_cbam = cbam_block(encoder_pool1, reduction)

    encoder_conv2 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    encoder_pool2 = MaxPooling2D()(encoder_conv2)

    encoder_pool2_cbam = cbam_block(encoder_pool2, reduction)

    encoder_conv3 = Conv2D(32, 3, activation='relu', padding='same')(inputs)
    encoder_pool3 = MaxPooling2D()(encoder_conv3)

    encoder_pool3_cbam = cbam_block(encoder_pool3, reduction)

    encoder_conv4 = Conv2D(16, 3, activation='relu', padding='same')(inputs)
    encoder_pool4 = MaxPooling2D()(encoder_conv4)

    encoder_pool4_cbam = cbam_block(encoder_pool4, reduction)

    encoder_conv5 = Conv2D(8, 3, activation='relu', padding='same')(encoder_pool1_cbam)
    encoder_pool5 = MaxPooling2D()(encoder_conv5)





    # Continue building the encoder ...

    # Decoder
    # Add CBAM block after the first decoder block
    decoder_upsample1 = UpSampling2D()(encoder_pool5)
    decoder_upsample1_cbam = cbam_block(decoder_upsample1, reduction)
    decoder_concat1 = Concatenate(axis=-1)([encoder_conv5, decoder_upsample1_cbam])
    decoder_conv4 = Conv2D(8, 3, activation='relu', padding='same')(decoder_concat1)

    decoder_upsample1 = UpSampling2D()(encoder_pool4)
    decoder_upsample1_cbam = cbam_block(decoder_upsample1, reduction)
    decoder_concat1 = Concatenate(axis=-1)([encoder_conv4, decoder_upsample1_cbam])
    decoder_conv4 = Conv2D(16, 3, activation='relu', padding='same')(decoder_concat1)

    decoder_upsample1 = UpSampling2D()(encoder_pool3)
    decoder_upsample1_cbam = cbam_block(decoder_upsample1, reduction)
    decoder_concat1 = Concatenate(axis=-1)([encoder_conv3, decoder_upsample1_cbam])
    decoder_conv4 = Conv2D(32, 3, activation='relu', padding='same')(decoder_concat1)

    decoder_upsample1 = UpSampling2D()(encoder_pool2)
    decoder_upsample1_cbam = cbam_block(decoder_upsample1, reduction)
    decoder_concat1 = Concatenate(axis=-1)([encoder_conv2, decoder_upsample1_cbam])
    decoder_conv4 = Conv2D(64, 3, activation='relu', padding='same')(decoder_concat1)

    decoder_upsample1 = UpSampling2D()(encoder_pool1)
    decoder_upsample1_cbam = cbam_block(decoder_upsample1, reduction)
    decoder_concat1 = Concatenate(axis=-1)([encoder_conv1, decoder_upsample1_cbam])
    decoder_conv4 = Conv2D(128, 3, activation='relu', padding='same')(decoder_concat1)

    # Continue building the decoder ...

    # Output
    outputs = Conv2D(num_classes, 1, activation='softmax')(decoder_convN)  # N: Number of decoder blocks

    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    return model
'''

# %%
'''

##############    UNet    #################


def Convolution(input_tensor,filters):

    x = Conv2D(filters=filters,kernel_size=(3, 3),padding = 'same',strides=(1, 1))(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def model(input_shape):

    inputs = Input((input_shape))

    conv_1 = Convolution(inputs,32)
    maxp_1 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_1)

    conv_2 = Convolution(maxp_1,64)
    maxp_2 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_2)

    conv_3 = Convolution(maxp_2,128)
    maxp_3 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_3)

    conv_4 = Convolution(maxp_3,256)
    maxp_4 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_4)

    conv_5 = Convolution(maxp_4,512)
    upsample_6 = UpSampling2D((2, 2)) (conv_5)

    conv_6 = Convolution(upsample_6,256)
    upsample_7 = UpSampling2D((2, 2)) (conv_6)

    upsample_7 = concatenate([upsample_7, conv_3])

    conv_7 = Convolution(upsample_7,128)
    upsample_8 = UpSampling2D((2, 2)) (conv_7)

    conv_8 = Convolution(upsample_8,64)
    upsample_9 = UpSampling2D((2, 2)) (conv_8)

    upsample_9 = concatenate([upsample_9, conv_1])

    conv_9 = Convolution(upsample_9,32)
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv_9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

  '''
# Out:
# "\n\n##############    UNet    #################\n\n\ndef Convolution(input_tensor,filters):\n\n    x = Conv2D(filters=filters,kernel_size=(3, 3),padding = 'same',strides=(1, 1))(input_tensor)\n    x = BatchNormalization()(x)\n    x = Activation('relu')(x)\n    return x\n\ndef model(input_shape):\n\n    inputs = Input((input_shape))\n\n    conv_1 = Convolution(inputs,32)\n    maxp_1 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_1)\n\n    conv_2 = Convolution(maxp_1,64)\n    maxp_2 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_2)\n\n    conv_3 = Convolution(maxp_2,128)\n    maxp_3 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_3)\n\n    conv_4 = Convolution(maxp_3,256)\n    maxp_4 = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same') (conv_4)\n\n    conv_5 = Convolution(maxp_4,512)\n    upsample_6 = UpSampling2D((2, 2)) (conv_5)\n\n    conv_6 = Convolution(upsample_6,256)\n    upsample_7 = UpSampling2D((2, 2)) (conv_6)\n\n    upsample_7 = concatenate([upsample_7, conv_3])\n\n    conv_7 = Convolution(upsample_7,128)\n    upsample_8 = UpSampling2D((2, 2)) (conv_7)\n\n    conv_8 = Convolution(upsample_8,64)\n    upsample_9 = UpSampling2D((2, 2)) (conv_8)\n\n    upsample_9 = concatenate([upsample_9, conv_1])\n\n    conv_9 = Convolution(upsample_9,32)\n    outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv_9)\n\n    model = Model(inputs=[inputs], outputs=[outputs])\n\n    return model\n\n  "

# %%
# Loding the Light weighted CNN
#model = model(input_shape = (240,240,1))    #unet
model=Attention_UNet(input_shape = (240,240,1))    #attention unet
#model= cbam_block(input_tensor = (240,240,1) , features=3)        #cbam
model.summary()
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 240, 240, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 240, 240, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 240, 240, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 240, 240, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 240, 240, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 240, 240, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 240, 240, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 120, 120, 32  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 120, 120, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 120, 120, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 120, 120, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 120, 120, 64  36928       ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 120, 120, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 120, 120, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 64)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 60, 60, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 60, 60, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 60, 60, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 60, 60, 128)  16512       ['activation_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 60, 60, 128)  147584     ['conv2d_6[0][0]']
#  ose)
#
#  conv2d_5 (Conv2D)              (None, 60, 60, 128)  32896       ['activation_3[0][0]']
#
#  add (Add)                      (None, 60, 60, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  activation_5 (Activation)      (None, 60, 60, 128)  0           ['add[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 60, 60, 1)    129         ['activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 60, 60, 1)    0           ['conv2d_7[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 120, 120, 1)  0           ['activation_6[0][0]']
#
#  lambda (Lambda)                (None, 120, 120, 64  0           ['up_sampling2d[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 120, 120, 64  0           ['lambda[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 120, 120, 64  4160        ['multiply[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 120, 120, 64  256        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 60, 60, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 60, 60, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 60, 60, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 60, 60, 128)  147584      ['activation_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 60, 60, 128)  512        ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 60, 60, 128)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 128)  0          ['activation_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 30, 30, 256)  33024       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 30, 30, 256)  1024       ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 30, 30, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 30, 30, 256)  65792       ['activation_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 30, 30, 256)  590080     ['conv2d_13[0][0]']
#  spose)
#
#  conv2d_12 (Conv2D)             (None, 30, 30, 256)  131328      ['activation_8[0][0]']
#
#  add_1 (Add)                    (None, 30, 30, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  activation_10 (Activation)     (None, 30, 30, 256)  0           ['add_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 30, 30, 1)    257         ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 30, 30, 1)    0           ['conv2d_14[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 60, 60, 1)   0           ['activation_11[0][0]']
#
#  lambda_1 (Lambda)              (None, 60, 60, 128)  0           ['up_sampling2d_1[0][0]']
#
#  multiply_1 (Multiply)          (None, 60, 60, 128)  0           ['lambda_1[0][0]',
#                                                                   'activation_8[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 60, 60, 128)  16512       ['multiply_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 60, 60, 128)  512        ['conv2d_15[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 128)  0          ['batch_normalization_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 30, 30, 256)  295168      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 30, 30, 256)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 30, 30, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 30, 30, 256)  0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 15, 15, 256)  0          ['activation_13[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 15, 15, 128)  32896       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 15, 15, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 15, 15, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 15, 15, 128)  16512       ['activation_14[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 15, 15, 128)  147584     ['conv2d_20[0][0]']
#  spose)
#
#  conv2d_19 (Conv2D)             (None, 15, 15, 128)  131200      ['activation_13[0][0]']
#
#  add_2 (Add)                    (None, 15, 15, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  activation_15 (Activation)     (None, 15, 15, 128)  0           ['add_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 15, 15, 1)    129         ['activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 15, 15, 1)    0           ['conv2d_21[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 30, 30, 1)   0           ['activation_16[0][0]']
#
#  lambda_2 (Lambda)              (None, 30, 30, 256)  0           ['up_sampling2d_2[0][0]']
#
#  multiply_2 (Multiply)          (None, 30, 30, 256)  0           ['lambda_2[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 30, 30, 256)  65792       ['multiply_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 15, 15, 256)  0          ['batch_normalization_13[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 15, 15, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 15, 15, 512)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 15, 15, 512)  2359808     ['activation_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 15, 15, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 15, 15, 512)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 15, 15, 256)  131328      ['activation_18[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 15, 15, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 15, 15, 256)  65792       ['activation_19[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 15, 15, 256)  590080     ['conv2d_27[0][0]']
#  spose)
#
#  conv2d_26 (Conv2D)             (None, 15, 15, 256)  262400      ['activation_13[0][0]']
#
#  add_3 (Add)                    (None, 15, 15, 256)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  activation_20 (Activation)     (None, 15, 15, 256)  0           ['add_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 15, 15, 1)    257         ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 15, 15, 1)    0           ['conv2d_28[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 30, 30, 1)   0           ['activation_21[0][0]']
#
#  lambda_3 (Lambda)              (None, 30, 30, 256)  0           ['up_sampling2d_3[0][0]']
#
#  multiply_3 (Multiply)          (None, 30, 30, 256)  0           ['lambda_3[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 30, 30, 256)  65792       ['multiply_3[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 30, 30, 512)  0          ['activation_18[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 30, 30, 768)  0           ['up_sampling2d_4[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 30, 30, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 30, 30, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 30, 30, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 30, 30, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 30, 30, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 30, 30, 128)  32896       ['activation_23[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 30, 30, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 30, 30, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 30, 30, 128)  16512       ['activation_24[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 30, 30, 128)  147584     ['conv2d_34[0][0]']
#  spose)
#
#  conv2d_33 (Conv2D)             (None, 30, 30, 128)  65664       ['activation_8[0][0]']
#
#  add_4 (Add)                    (None, 30, 30, 128)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  activation_25 (Activation)     (None, 30, 30, 128)  0           ['add_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 30, 30, 1)    129         ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 30, 30, 1)    0           ['conv2d_35[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 60, 60, 1)   0           ['activation_26[0][0]']
#
#  lambda_4 (Lambda)              (None, 60, 60, 128)  0           ['up_sampling2d_5[0][0]']
#
#  multiply_4 (Multiply)          (None, 60, 60, 128)  0           ['lambda_4[0][0]',
#                                                                   'activation_8[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 60, 60, 128)  16512       ['multiply_4[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 60, 60, 256)  0          ['activation_23[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 60, 60, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 60, 60, 384)  0           ['up_sampling2d_6[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 60, 60, 128)  442496      ['concatenate_2[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 60, 60, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 60, 60, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 60, 60, 128)  147584      ['activation_27[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 60, 60, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 60, 60, 128)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 60, 60, 64)   8256        ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 60, 60, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 60, 60, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 60, 60, 64)   4160        ['activation_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 60, 60, 64)  36928       ['conv2d_41[0][0]']
#  spose)
#
#  conv2d_40 (Conv2D)             (None, 60, 60, 64)   16448       ['activation_3[0][0]']
#
#  add_5 (Add)                    (None, 60, 60, 64)   0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  activation_30 (Activation)     (None, 60, 60, 64)   0           ['add_5[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 60, 60, 1)    65          ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 60, 60, 1)    0           ['conv2d_42[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 120, 120, 1)  0          ['activation_31[0][0]']
#
#  lambda_5 (Lambda)              (None, 120, 120, 64  0           ['up_sampling2d_7[0][0]']
#                                 )
#
#  multiply_5 (Multiply)          (None, 120, 120, 64  0           ['lambda_5[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 120, 120, 64  4160        ['multiply_5[0][0]']
#                                 )
#
#  up_sampling2d_8 (UpSampling2D)  (None, 120, 120, 12  0          ['activation_28[0][0]']
#                                 8)
#
#  batch_normalization_25 (BatchN  (None, 120, 120, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 120, 120, 19  0           ['up_sampling2d_8[0][0]',
#                                 2)                                'batch_normalization_25[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 120, 120, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 120, 120, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_32 (Activation)     (None, 120, 120, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 120, 120, 64  36928       ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 120, 120, 64  256        ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 120, 120, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 120, 120, 32  2080        ['activation_33[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 120, 120, 32  128        ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 120, 120, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 120, 120, 32  1056        ['activation_34[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 120, 120, 32  9248       ['conv2d_48[0][0]']
#  spose)                         )
#
#  conv2d_47 (Conv2D)             (None, 120, 120, 32  4128        ['activation_1[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 120, 120, 32  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'conv2d_47[0][0]']
#
#  activation_35 (Activation)     (None, 120, 120, 32  0           ['add_6[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 120, 120, 1)  33          ['activation_35[0][0]']
#
#  activation_36 (Activation)     (None, 120, 120, 1)  0           ['conv2d_49[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 240, 240, 1)  0          ['activation_36[0][0]']
#
#  lambda_6 (Lambda)              (None, 240, 240, 32  0           ['up_sampling2d_9[0][0]']
#                                 )
#
#  multiply_6 (Multiply)          (None, 240, 240, 32  0           ['lambda_6[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 240, 240, 32  1056        ['multiply_6[0][0]']
#                                 )
#
#  up_sampling2d_10 (UpSampling2D  (None, 240, 240, 64  0          ['activation_33[0][0]']
#  )                              )
#
#  batch_normalization_29 (BatchN  (None, 240, 240, 32  128        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  concatenate_4 (Concatenate)    (None, 240, 240, 96  0           ['up_sampling2d_10[0][0]',
#                                 )                                 'batch_normalization_29[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 240, 240, 32  27680       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_30 (BatchN  (None, 240, 240, 32  128        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 240, 240, 32  0           ['batch_normalization_30[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 240, 240, 32  9248        ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 240, 240, 32  128        ['conv2d_52[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 240, 240, 32  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 240, 240, 1)  33          ['activation_38[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 240, 240, 1)  4          ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 240, 240, 1)  0           ['batch_normalization_32[0][0]']
#
# ==================================================================================================
# Total params: 10,788,812
# Trainable params: 10,779,082
# Non-trainable params: 9,730
# __________________________________________________________________________________________________

# %%
# Computing Dice_Coefficient
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Computing Precision
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# Computing Sensitivity
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Compiling the model
Adam=optimizers.Adam(lr=0.001)
model.compile(optimizer=Adam, loss='binary_crossentropy', metrics=['accuracy',dice_coef,precision,sensitivity,specificity])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Fitting the model over the data
history = model.fit(X_train,Y_train,batch_size=32,epochs=40,validation_split=0.20,verbose=1,initial_epoch=0)
# Out:
# Epoch 1/40
# 66/66 [==============================] - 140s 2s/step - loss: 0.6780 - accuracy: 0.7674 - dice_coef: 0.0784 - precision: 0.0651 - sensitivity: 0.9802 - specificity: 0.7752 - val_loss: 1.0683 - val_accuracy: 0.0029 - val_dice_coef: 0.0568 - val_precision: 0.0117 - val_sensitivity: 0.9999 - val_specificity: 8.3835e-04
# Epoch 2/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.6274 - accuracy: 0.8624 - dice_coef: 0.0795 - precision: 0.0955 - sensitivity: 0.9921 - specificity: 0.8712 - val_loss: 0.7445 - val_accuracy: 0.8645 - val_dice_coef: 0.0708 - val_precision: 0.0824 - val_sensitivity: 0.9689 - val_specificity: 0.8728
# Epoch 3/40
# Epoch 12/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.4044 - accuracy: 0.9222 - dice_coef: 0.0917 - precision: 0.1648 - sensitivity: 0.9595 - specificity: 0.9322 - val_loss: 0.3981 - val_accuracy: 0.9883 - val_dice_coef: 0.0562 - val_precision: 149011759104.0000 - val_sensitivity: 0.8256 - val_specificity: 1.0000
# Epoch 13/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.3847 - accuracy: 0.9277 - dice_coef: 0.0922 - precision: 0.1784 - sensitivity: 0.9528 - specificity: 0.9379 - val_loss: 0.3575 - val_accuracy: 0.9530 - val_dice_coef: 0.0747 - val_precision: 0.2529 - val_sensitivity: 0.9047 - val_specificity: 0.9633
# Epoch 14/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.3690 - accuracy: 0.9265 - dice_coef: 0.0953 - precision: 0.1733 - sensitivity: 0.9603 - specificity: 0.9365 - val_loss: 0.3716 - val_accuracy: 0.9882 - val_dice_coef: 0.0660 - val_precision: 51744706560.0000 - val_sensitivity: 0.8264 - val_specificity: 0.9999
# Epoch 15/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.3612 - accuracy: 0.9309 - dice_coef: 0.0954 - precision: 0.3271 - sensitivity: 0.9427 - specificity: 0.9413 - val_loss: 0.8742 - val_accuracy: 0.2006 - val_dice_coef: 0.0693 - val_precision: 0.0146 - val_sensitivity: 0.9993 - val_specificity: 0.2007
# Epoch 16/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.3432 - accuracy: 0.9381 - dice_coef: 0.0959 - precision: 0.6882 - sensitivity: 0.9270 - specificity: 0.9487 - val_loss: 0.3602 - val_accuracy: 0.9144 - val_dice_coef: 0.0856 - val_precision: 0.1308 - val_sensitivity: 0.9566 - val_specificity: 0.9235
# Epoch 17/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.3301 - accuracy: 0.9477 - dice_coef: 0.0969 - precision: 1.4650 - sensitivity: 0.9060 - specificity: 0.9587 - val_loss: 0.3368 - val_accuracy: 0.9379 - val_dice_coef: 0.0836 - val_precision: 0.1843 - val_sensitivity: 0.9336 - val_specificity: 0.9476
# Epoch 18/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.3173 - accuracy: 0.9411 - dice_coef: 0.0993 - precision: 0.2338 - sensitivity: 0.9255 - specificity: 0.9518 - val_loss: 0.3028 - val_accuracy: 0.9882 - val_dice_coef: 0.0804 - val_precision: 7462940672.0000 - val_sensitivity: 0.8263 - val_specificity: 0.9998
# Epoch 19/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.3055 - accuracy: 0.9446 - dice_coef: 0.1023 - precision: 0.4410 - sensitivity: 0.9215 - specificity: 0.9555 - val_loss: 0.3036 - val_accuracy: 0.9874 - val_dice_coef: 0.0813 - val_precision: 17.0600 - val_sensitivity: 0.8280 - val_specificity: 0.9990
# Epoch 20/40
# Epoch 29/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.2180 - accuracy: 0.9814 - dice_coef: 0.1178 - precision: 3.2125 - sensitivity: 0.7641 - specificity: 0.9941 - val_loss: 0.2271 - val_accuracy: 0.9876 - val_dice_coef: 0.0901 - val_precision: 8.9786 - val_sensitivity: 0.7939 - val_specificity: 0.9992
# Epoch 30/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.2112 - accuracy: 0.9846 - dice_coef: 0.1176 - precision: 3.9377 - sensitivity: 0.7513 - specificity: 0.9974 - val_loss: 0.2179 - val_accuracy: 0.9316 - val_dice_coef: 0.1285 - val_precision: 0.1624 - val_sensitivity: 0.9195 - val_specificity: 0.9412
# Epoch 31/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.2114 - accuracy: 0.9795 - dice_coef: 0.1164 - precision: 3.5612 - sensitivity: 0.7624 - specificity: 0.9921 - val_loss: 0.2956 - val_accuracy: 0.9140 - val_dice_coef: 0.1398 - val_precision: 0.1199 - val_sensitivity: 0.8807 - val_specificity: 0.9230
# Epoch 32/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.2015 - accuracy: 0.9846 - dice_coef: 0.1188 - precision: 5.3081 - sensitivity: 0.7416 - specificity: 0.9974 - val_loss: 0.1980 - val_accuracy: 0.9851 - val_dice_coef: 0.1166 - val_precision: 2.1015 - val_sensitivity: 0.7234 - val_specificity: 0.9966
# Epoch 33/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1939 - accuracy: 0.9837 - dice_coef: 0.1223 - precision: 5.7172 - sensitivity: 0.7269 - specificity: 0.9965 - val_loss: 0.1876 - val_accuracy: 0.9881 - val_dice_coef: 0.0826 - val_precision: 28000000000.0000 - val_sensitivity: 0.6815 - val_specificity: 0.9997
# Epoch 34/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.1878 - accuracy: 0.9825 - dice_coef: 0.1281 - precision: 3.6410 - sensitivity: 0.7328 - specificity: 0.9952 - val_loss: 0.1767 - val_accuracy: 0.9880 - val_dice_coef: 0.1001 - val_precision: 12.9690 - val_sensitivity: 0.7188 - val_specificity: 0.9996
# Epoch 35/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1809 - accuracy: 0.9823 - dice_coef: 0.1312 - precision: 2.2375 - sensitivity: 0.7275 - specificity: 0.9951 - val_loss: 0.1652 - val_accuracy: 0.9883 - val_dice_coef: 0.0968 - val_precision: 25397057536.0000 - val_sensitivity: 0.7225 - val_specificity: 1.0000
# Epoch 36/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1802 - accuracy: 0.9843 - dice_coef: 0.1243 - precision: 6.8872 - sensitivity: 0.7333 - specificity: 0.9972 - val_loss: 0.1841 - val_accuracy: 0.9859 - val_dice_coef: 0.1049 - val_precision: 3.7991 - val_sensitivity: 0.7295 - val_specificity: 0.9973
# Epoch 37/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1763 - accuracy: 0.9858 - dice_coef: 0.1284 - precision: 8.5165 - sensitivity: 0.7106 - specificity: 0.9987 - val_loss: 0.1664 - val_accuracy: 0.9883 - val_dice_coef: 0.0915 - val_precision: 51102941184.0000 - val_sensitivity: 0.6841 - val_specificity: 0.9999
# Epoch 38/40
# 66/66 [==============================] - 78s 1s/step - loss: 0.1803 - accuracy: 0.9826 - dice_coef: 0.1194 - precision: 3.4824 - sensitivity: 0.6213 - specificity: 0.9955 - val_loss: 0.2403 - val_accuracy: 0.9591 - val_dice_coef: 0.0967 - val_precision: 0.1697 - val_sensitivity: 0.4889 - val_specificity: 0.9698
# Epoch 39/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1701 - accuracy: 0.9855 - dice_coef: 0.1228 - precision: 6.2025 - sensitivity: 0.7404 - specificity: 0.9984 - val_loss: 0.1770 - val_accuracy: 0.9798 - val_dice_coef: 0.1102 - val_precision: 1.3038 - val_sensitivity: 0.6691 - val_specificity: 0.9912
# Epoch 40/40
# 66/66 [==============================] - 79s 1s/step - loss: 0.1672 - accuracy: 0.9856 - dice_coef: 0.1275 - precision: 6.2021 - sensitivity: 0.6958 - specificity: 0.9985 - val_loss: 0.1592 - val_accuracy: 0.9883 - val_dice_coef: 0.0682 - val_precision: 41946468352.0000 - val_sensitivity: 0.2185 - val_specificity: 1.0000

# %%
# Evaluating the model on the training and testing data
model.evaluate(x=X_train, y=Y_train, batch_size=32 , verbose=1, sample_weight=None, steps=None)
model.evaluate(x=X_test, y=Y_test, batch_size=32, verbose=1, sample_weight=None, steps=None)
# Out:
# 83/83 [==============================] - 28s 339ms/step - loss: 0.1635 - accuracy: 0.9872 - dice_coef: 0.0749 - precision: 57167839232.0000 - sensitivity: 0.2606 - specificity: 1.0000
# 15/15 [==============================] - 10s 667ms/step - loss: 0.1661 - accuracy: 0.9864 - dice_coef: 0.0784 - precision: 64088002560.0000 - sensitivity: 0.2643 - specificity: 1.0000
# [0.1661001443862915,
#  0.9863878488540649,
#  0.07839622348546982,
#  64088002560.0,
#  0.2642548680305481,
#  0.9999999403953552]

# %%
# Accuracy vs Epoch
def Accuracy_Graph(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    #plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)
    plt.show()

# Dice Similarity Coefficient vs Epoch
def Dice_coefficient_Graph(history):

    plt.plot(history.history['dice_coef'])
    plt.plot(history.history['val_dice_coef'])
    #plt.title('Dice_Coefficient')
    plt.ylabel('Dice_Coefficient')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)
    plt.show()
# Loss vs Epoch
def Loss_Graph(history):

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    #plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)
    plt.show()

# Mean IoU


IoU_values=[]
for img in range (0,X_test.shape[0]):
  temp_img=X_test[img]
  ground_truth=Y_test[img]
  gt=ground_truth.squeeze()>0
  temp_img_input=np.expand_dims(temp_img,0)
  prediction= (model.predict(temp_img_input)[0,:,:,0]>0.5).astype(np.uint8)

  IoU=MeanIoU(num_classes=n_classes)
  IoU.update_state(ground_truth[:,:,0],prediction)
  IoU=IoU.result().numpy()
  IoU_values.append(IoU)

# %%
# experimenting with the IoUs
print(X_train.shape , X_test.shape, Y_train.shape, Y_test.shape)
# IoU=[]
# for i range(len(X_test)):
#   im1=Y_test[i]
#   im2=Y_test[i]

# %%
# Plotting the Graphs of Accuracy, Dice_coefficient, Loss at each epoch on Training and Testing data
Accuracy_Graph(history)
Dice_coefficient_Graph(history)
Loss_Graph(history)

# %%
from keras.utils import plot_model
plot_model(model,to_file='model.png')

# %%
model.save('./BraTs2020.h5')

# %%
model.load_weights('./BraTs2020.h5')

# %%
X_train=X_test=Y_train=Y_test=0

# %%
fig = plt.figure(figsize=(5,5))
immmg = TR[250,:,:]
imgplot = plt.imshow(immmg)
plt.show()

# %%
pref_Tumor = model.predict(TR)
# Out:
# 97/97 [==============================] - 28s 281ms/step

# %%
fig = plt.figure(figsize=(5,5))
immmg = pref_Tumor[250,:,:,0]
imgplot = plt.imshow(immmg)
plt.show()

# %%
plt.figure(figsize=(15,10))


plt.subplot(341)
plt.title('Sample 1')
plt.axis('off')
plt.imshow(np.squeeze(TR[250,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[250,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(342)
plt.title('Sample 2')
plt.axis('off')
plt.imshow(np.squeeze(TR[550,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[550,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(343)
plt.title('Sample 3')
plt.axis('off')
plt.imshow(np.squeeze(TR[400,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[400,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(344)
plt.title('Sample 4')
plt.axis('off')
plt.imshow(np.squeeze(TR[690,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[690,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(345)
plt.title('Sample 5')
plt.axis('off')
plt.imshow(np.squeeze(TR[850,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[850,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(346)
plt.title('Sample 6')
plt.axis('off')
plt.imshow(np.squeeze(TR[1450,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[1450,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(347)
plt.title('Sample 7')
plt.axis('off')
plt.imshow(np.squeeze(TR[1800,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[1800,:,:]),alpha=0.3,cmap='Reds')

plt.subplot(348)
plt.title('Sample 8')
plt.axis('off')
plt.imshow(np.squeeze(TR[60,:,:]),cmap='gray')
plt.imshow(np.squeeze(pref_Tumor[60,:,:]),alpha=0.3,cmap='Reds')
